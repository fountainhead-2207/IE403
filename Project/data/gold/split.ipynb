# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv("gold_Qwen3.7_max.csv")

# %%
df.dropna(subset=['sarcasm_label'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.dropna(columns=['sarcasm_label'], inplace=True)
#
# TypeError: DataFrame.dropna() got an unexpected keyword argument 'columns'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7978 entries, 0 to 7977
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   platform                7978 non-null   object
#  1   video_id                7978 non-null   object
#  2   video_url               7978 non-null   object
#  3   video_title             7978 non-null   object
#  4   video_core_content      7978 non-null   object
#  5   video_target_sentiment  7978 non-null   object
#  6   video_highlight         7978 non-null   object
#  7   comment                 7975 non-null   object
#  8   commonsense             7917 non-null   object
#  9   sarcasm_label           7877 non-null   object
#  10  reasoning               7877 non-null   object
# dtypes: object(11)
# memory usage: 685.7+ KB

# %%
train_df, test_df = train_test_split(df, test_size=0.1, stratify=df['sarcasm_label'], random_state=42)

# 3. Lưu thành 2 file riêng biệt
train_df.to_csv("train_data.csv", index=False)
test_df.to_csv("test_data.csv", index=False)

print(f"Số mẫu Train: {len(train_df)}")
print(f"Số mẫu Test: {len(test_df)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 train_df, test_df = train_test_split(df, test_size=0.1, stratify=df['sarcasm_label'], random_state=42)
#       3 # 3. Lưu thành 2 file riêng biệt
#       4 train_df.to_csv("train_data.csv", index=False)
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
# ...
