# %%
import os
import json
import time
import re
import pandas as pd
import concurrent.futures
import httpx
from tqdm import tqdm

from openai import OpenAI

# %%
TOGETHER_API_KEY = "Your_Together_API_Key_Here"
client = OpenAI(
    api_key=TOGETHER_API_KEY,
    base_url="https://api.together.ai/v1",
    timeout=httpx.Timeout(120.0) 
)

MODEL_JUDGE = "Qwen/Qwen3-235B-A22B-Instruct-2507-tput"

# %%
# ==========================================
# 2. HÀM GỌI API GÁN NHÃN (ĐÃ FIX LỖI STREAM CHUNK RỖNG)
# ==========================================
def get_sarcasm_labels_qwen(batch_data):
    system_prompt = """Bạn là một CHUYÊN GIA NGÔN NGỮ HỌC và HỆ THỐNG ĐÁNH GIÁ (LLM-as-a-Judge) cấp cao.
Nhiệm vụ của bạn là gán nhãn "Sarcastic" (Mỉa mai) hoặc "Non-Sarcastic" (Không mỉa mai) cho các bình luận.

<sarcasm_guideline>
<data_priority_rule>
LƯU Ý VỀ ĐỘ TIN CẬY CỦA DỮ LIỆU:
1. [Context] (Ngữ cảnh) và [Comment] (Bình luận) là sự thật tuyệt đối, BẮT BUỘC phải dựa vào đây để đánh giá.
2. [Commonsense] (Kiến thức nền) CHỈ LÀ THÔNG TIN THAM KHẢO để hỗ trợ giải nghĩa từ lóng. Nếu bạn phát hiện [Commonsense] có dấu hiệu ngây ngô, suy diễn sai lệch, hoặc mâu thuẫn với logic hiển nhiên của [Context], HÃY NGAY LẬP TỨC BỎ QUA [Commonsense] và tự suy luận dựa trên [Context].
</data_priority_rule>

ĐỊNH NGHĨA HỌC THUẬT VỀ SARCASM (MỈA MAI):
Mỉa mai là một hình thức châm biếm bằng lời nói (verbal irony), thường dùng để chế nhạo, chỉ trích hoặc thể hiện sự khinh miệt một cách gián tiếp. 

Đặc trưng cốt lõi của Mỉa mai là "SỰ MÂU THUẪN" (Incongruity). Hãy tìm kiếm 3 dấu hiệu sau:
1. Mâu thuẫn với Ngữ cảnh (Contextual Incongruity): Ý nghĩa bề mặt của bình luận (thường là tích cực) trái ngược hoàn toàn với sự thật hiển nhiên được cung cấp trong [Context] và [Commonsense].
2. Lời khen giả tạo (False Praise): Khen ngợi một người/sự kiện thực chất đang rất tồi tệ, thất bại hoặc đầy tai tiếng.
3. Vi phạm kỳ vọng thực tế (Pragmatic Expectation Violation): Dùng một hình ảnh so sánh tâng bốc (Hyperbole) đặt cạnh một đối tượng có đặc điểm hoàn toàn trái ngược trong đời thực.

ĐẶC TRƯNG "ĐÁ XÉO / CÀ KHỊA" TRONG TIẾNG VIỆT:
Ngoài định nghĩa cốt lõi, hãy đặc biệt chú ý 3 hình thái mỉa mai ngầm ẩn (đá xéo) cực kỳ phổ biến sau:
1. Lịch sự giả tạo (Mock Politeness / Nói mát): Dùng từ ngữ nhún nhường, xưng hô trang trọng hoặc khen ngợi thái quá ("dạ vâng", "anh thì nhất rồi", "giỏi ghê ha") đối với một hành vi sai trái/người có lỗi. -> Sarcastic.
2. Khen ngợi lạc đề / Hiển nhiên (Irrelevant Praise): Khen ngợi một điều quá đỗi hiển nhiên, lặt vặt (VD: "Ít ra anh ấy mặc áo đẹp") khi bối cảnh đang đề cập đến một thất bại lớn về chuyên môn, nhằm hạ thấp năng lực thực sự. -> Sarcastic.
3. Dấu hiệu ngôn ngữ tình thái: Các từ cuối câu như "nhỉ", "ghê", "ha", "cơ", "á", "thay" khi đặt cạnh một tính từ tích cực trong một hoàn cảnh tiêu cực. -> Sarcastic.

HƯỚNG DẪN CHẤM ĐIỂM (REASONING CHAIN):
- NẾU: Bình luận chứa lời khen/đồng tình + [Context/Thực tế] xác nhận thực tế là tồi tệ/thất bại => Sarcastic (Lời khen giả tạo).
- NẾU: Bình luận là câu hỏi tu từ mang tính thách thức, ngầm phủ định sự thật (VD: "Làm như hay lắm không bằng?") => Sarcastic.
- NẾU: Bình luận dùng thành ngữ/tục ngữ kết hợp với lời tâng bốc thái quá, phi lý so với thực tế => Sarcastic.
- NẾU: Bình luận dùng thành ngữ/ẩn dụ (VD: "Nồi nào úp vung nấy") để chê bai TRỰC TIẾP, không mượn vỏ bọc khen ngợi => Non-Sarcastic.
- NẾU: Bình luận chê bai/chửi bới trực tiếp, khen ngợi đúng với sự thật hiển nhiên, hoặc chỉ là câu hỏi thắc mắc tìm kiếm thông tin thật => Non-Sarcastic.
</sarcasm_guideline>

<examples>
HÃY HỌC TẬP CÁCH PHÂN TÍCH QUA CÁC VÍ DỤ SAU:
- [Context]: Một người lái xe ẩu gây tai nạn. | [Comment]: "Trình độ lái xe điêu luyện quá cơ, nhắm mắt cũng đâm trúng."
  -> Nhãn: Sarcastic. (Reasoning: Dùng từ khen ngợi "điêu luyện" + từ tình thái "quá cơ" cho một hành vi gây tai nạn tồi tệ).
  
- [Context]: Một bộ phim bị giới phê bình chê tơi tả về nội dung. | [Comment]: "Tuyệt vời, ít ra diễn viên có mặc quần áo."
  -> Nhãn: Sarcastic. (Reasoning: Khen ngợi một đặc điểm hiển nhiên, vô thưởng vô phạt để ngầm chê nội dung phim).

- [Context]: Cầu thủ A sút hỏng phạt đền. | [Comment]: "Đúng là thằng phế vật, sút ngu như bò."
  -> Nhãn: Non-Sarcastic. (Reasoning: Chửi bới, chê bai trực tiếp không có lớp vỏ bọc ẩn ý).
</examples>

<output_format>
BẠN BẮT BUỘC TRẢ VỀ JSON CHỨA MẢNG "results". MỖI PHẦN TỬ GỒM:
- "id": Trích xuất từ Input.
- "comment": Trích xuất nguyên văn bình luận để làm mỏ neo.
- "sarcasm_label": BẮT BUỘC LÀ "Sarcastic" HOẶC "Non-Sarcastic".
- "reasoning": 1 câu giải thích ngắn gọn (BẮT BUỘC DƯỚI 30 CHỮ) về sự mâu thuẫn giữa Comment và Ngữ cảnh (Context) để tiết kiệm token đầu ra.
</output_format>

BÂY GIỜ, HÃY PHÂN TÍCH VÀ GÁN NHÃN CHO BATCH DỮ LIỆU SAU:
"""

    user_prompt = "[Input Batch]\n"
    for item in batch_data:
        user_prompt += f"ID: {item['id']} | Context: {item['ctx']} | Comment: {item['cmt']} | Commonsense: {item['cs']}\n"
    user_prompt += "\n[Output (JSON)]:"

    for attempt in range(3):
        try:
            response = client.chat.completions.create(
                model=MODEL_JUDGE,
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": user_prompt}
                ],
                temperature=0.0,
                response_format={"type": "json_object"},
                max_tokens=4096,
                stream=False
            )
            
            content = response.choices[0].message.content or ""
                        
            if not content: 
                tqdm.write(f"⚠️ Batch rỗng nội dung (Lần {attempt+1}/3)")
                time.sleep(2)
                continue
                
            try:
                # Xóa các ký tự ẩn gây lỗi JSON
                content = re.sub(r'[\x00-\x1f]', '', content)
                result_json = json.loads(content, strict=False)
                
                if isinstance(result_json, list):
                    return result_json
                # Nếu Qwen trả về Dict (có bọc "results") -> Dùng .get()
                elif isinstance(result_json, dict):
                    return result_json.get("results", [])
                else:
                    return None
                    
            except json.JSONDecodeError as e:
                tqdm.write(f"⚠️ Lỗi parse JSON (Lần {attempt+1}/3): {e}. Đầu output: {content[:300]}")
                time.sleep(2)
                continue

        except Exception as e:
            tqdm.write(f"⚠️ Lỗi API Qwen Max (Lần {attempt+1}/3): {str(e)}")
            time.sleep(4) 
            
    return None

# %%
def process_single_batch(batch_info):
    batch_idx, batch_data = batch_info
    results = get_sarcasm_labels_qwen(batch_data)
    return batch_idx, results

# %%
def process_dataset_labeling(input_csv, output_csv, batch_size=15, max_workers=3):
    if os.path.exists(output_csv):
        print(f"\n[*] Tìm thấy file đang chạy dở: {output_csv}. Đang resume...")
        df = pd.read_csv(output_csv)
    else:
        print(f"\n[*] Chạy lần đầu. Đang đọc file Silver: {input_csv}")
        df = pd.read_csv(input_csv)
        df['sarcasm_label'] = None 
        df['reasoning'] = None
        df.to_csv(output_csv, index=False, encoding='utf-8-sig')
    
    if 'sarcasm_label' not in df.columns:
        df['sarcasm_label'] = None
        df['reasoning'] = None

    def needs_processing(x):
        return str(x).strip() in ['nan', 'None', '']

    pending_indices = df[df['sarcasm_label'].apply(needs_processing)].index.tolist()
    print(f"Tổng số dòng chờ Qwen Max gán nhãn: {len(pending_indices)} | Batch: {batch_size} | Luồng: {max_workers}")
    
    if not pending_indices:
        print("🎉 Mọi dữ liệu đã được gán nhãn hoàn tất 100%!")
        return

    # Chia mảng dữ liệu thành các cục (Batches)
    all_batches = []
    for i in range(0, len(pending_indices), batch_size):
        batch_indices = pending_indices[i:i+batch_size]
        batch_data = []
        for idx in batch_indices:
            ctx = str(df.at[idx, 'video_core_content']).replace('\n', ' ')
            cmt = str(df.at[idx, 'comment']).replace('\n', ' ')
            cs = str(df.at[idx, 'commonsense']).replace('\n', ' ')
            
            if cmt.lower() == 'nan' or cs.lower() == 'nan': 
                continue
                
            batch_data.append({"id": idx, "ctx": ctx, "cmt": cmt, "cs": cs})
        
        if batch_data:
            all_batches.append((i // batch_size, batch_data))

    print(f"🚀 Kích hoạt cỗ máy Giám khảo siêu cấp Qwen Max...")

    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(process_single_batch, b) for b in all_batches]
        
        for future in tqdm(concurrent.futures.as_completed(futures), total=len(futures), desc="Đang Judge (Qwen Max)"):
            batch_idx, results = future.result()
            
            if results:
                for res in results:
                    try:
                        row_id = int(res.get("id"))
                    except (TypeError, ValueError):
                        tqdm.write(f"⚠️ Bỏ qua kết quả có id không hợp lệ: {res}")
                        continue

                    label = res.get("sarcasm_label", "")
                    reason = res.get("reasoning", "")

                    if label not in ["Sarcastic", "Non-Sarcastic"]:
                        tqdm.write(f"⚠️ Bỏ qua nhãn không hợp lệ tại dòng {row_id}: {label}")
                        continue
                        
                    if row_id is not None and row_id in df.index:
                        df.at[row_id, 'sarcasm_label'] = str(label).strip()
                        df.at[row_id, 'reasoning'] = str(reason).strip()
            
            # Lưu đè liên tục để bảo vệ dữ liệu
            df.to_csv(output_csv, index=False, encoding='utf-8-sig')

    print(f"\n[HOÀN THÀNH TẬP GOLD DATA] Toàn bộ dữ liệu nhãn chuẩn đã lưu tại: {output_csv}")

# %%
if __name__ == "__main__":
    INPUT_FILE = "silver_70B.csv" 
    OUTPUT_FILE = "gold_labeled_llama_70B.csv" 
    
    BATCH_SIZE = 10  
    MAX_WORKERS = 5
    
    if os.path.exists(INPUT_FILE):
        process_dataset_labeling(INPUT_FILE, OUTPUT_FILE, batch_size=BATCH_SIZE, max_workers=MAX_WORKERS)
    else:
        print(f"Lỗi: Không tìm thấy file gốc {INPUT_FILE}")
# Out:
# [*] Tìm thấy file đang chạy dở: gold_labeled_llama_70B.csv. Đang resume...
# Tổng số dòng chờ Qwen Max gán nhãn: 3466 | Batch: 10 | Luồng: 5
# 🚀 Kích hoạt cỗ máy Giám khảo siêu cấp Qwen Max...
# Đang Judge (Qwen Max):   0%|          | 0/347 [00:01<?, ?it/s]
# ⚠️ Lỗi API Qwen Max (Lần 1/3): Error code: 402 - {'id': 'omR8tJX-2j9zxn-a04dd0da683291a1', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 1/3): Error code: 402 - {'id': 'omR8tKk-2j9zxn-a04dd0da6b8cfd77', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# Đang Judge (Qwen Max):   0%|          | 0/347 [00:06<?, ?it/s]
# ⚠️ Lỗi API Qwen Max (Lần 2/3): Error code: 402 - {'id': 'omR8ucW-4YNCb4-a04dd0fd3be8fd77', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# Đang Judge (Qwen Max):   0%|          | 0/347 [00:10<?, ?it/s]
# ⚠️ Lỗi API Qwen Max (Lần 3/3): Error code: 402 - {'id': 'omR8vu5-4YNCb4-a04dd1185c3dfd77', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# Đang Judge (Qwen Max):   0%|          | 1/347 [00:14<1:23:55, 14.55s/it]
# ⚠️ Lỗi API Qwen Max (Lần 1/3): Error code: 402 - {'id': 'omR8xBU-2j9zxn-a04dd1335e24fd77', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# Đang Judge (Qwen Max):   0%|          | 1/347 [00:19<1:23:55, 14.55s/it]
# ⚠️ Lỗi API Qwen Max (Lần 2/3): Error code: 402 - {'id': 'omR8yTT-2j9zxn-a04dd14e5927fd77', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# Đang Judge (Qwen Max):   0%|          | 1/347 [00:21<2:02:09, 21.18s/it]
# ⚠️ Lỗi API Qwen Max (Lần 1/3): Error code: 402 - {'id': 'omR8zGm-2j9zxn-a04dd15f3ae79fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 3/3): Error code: 402 - {'id': 'omR8zwN-4YNCb4-a04dd16968b49fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 1/3): Error code: 402 - {'id': 'omR91KQ-4YNCb4-a04dd1752f819fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 2/3): Error code: 402 - {'id': 'omR91Zn-4YNCb4-a04dd17a5a289fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 1/3): Error code: 402 - {'id': 'omR92EL-4YNCb4-a04dd1885a589fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 2/3): Error code: 402 - {'id': 'omR92bX-2j9zxn-a04dd1905eda9fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 3/3): Error code: 402 - {'id': 'omR92r7-2j9zxn-a04dd19589e29fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 1/3): Error code: 402 - {'id': 'omR93JH-2j9zxn-a04dd19ef8789fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 2/3): Error code: 402 - {'id': 'omR93WZ-2j9zxn-a04dd1a37b7b9fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 3/3): Error code: 402 - {'id': 'omR941o-2j9zxn-a04dd1ab49799fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 1/3): Error code: 402 - {'id': 'omR948o-4YNCb4-a04dd1b06c9c9fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 2/3): Error code: 402 - {'id': 'omR94b8-2j9zxn-a04dd1ba0d6a9fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 3/3): Error code: 402 - {'id': 'omR94pK-4YNCb4-a04dd1be8a699fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 1/3): Error code: 402 - {'id': 'omR95Hw-2j9zxn-a04dd1c908389fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 2/3): Error code: 402 - {'id': 'omR95R2-2j9zxn-a04dd1cb89cf9fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 3/3): Error code: 402 - {'id': 'omR95sq-4YNCb4-a04dd1d50f189fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 1/3): Error code: 402 - {'id': 'omR9698-4YNCb4-a04dd1daaa409fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 1/3): Error code: 402 - {'id': 'omR96T8-2j9zxn-a04dd1e13d8e9fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 3/3): Error code: 402 - {'id': 'omR96ho-2j9zxn-a04dd1e6689fa8e1', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 2/3): Error code: 402 - {'id': 'omR96hx-4YNCb4-a04dd1e3eec99fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 1/3): Error code: 402 - {'id': 'omR97AW-4YNCb4-a04dd1f02cfd9fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 2/3): Error code: 402 - {'id': 'omR97RK-2j9zxn-a04dd1f5bfbb9fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 2/3): Error code: 402 - {'id': 'omR97uG-4YNCb4-a04dd1fc8b259fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 1/3): Error code: 402 - {'id': 'omR97zd-4YNCb4-a04dd2019956a8e1', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 3/3): Error code: 402 - {'id': 'omR98CZ-2j9zxn-a04dd2021e22d899', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 2/3): Error code: 402 - {'id': 'omR98T4-2j9zxn-a04dd20b5b8e9fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 3/3): Error code: 402 - {'id': 'omR98hm-2j9zxn-a04dd210ae609fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 3/3): Error code: 402 - {'id': 'omR99DF-4YNCb4-a04dd21adbee9fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 2/3): Error code: 402 - {'id': 'omR99HH-2j9zxn-a04dd21cb969a8e1', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 1/3): Error code: 402 - {'id': 'omR99Us-2j9zxn-a04dd220ff7b9fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 3/3): Error code: 402 - {'id': 'omR99jN-2j9zxn-a04dd2264af89fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}
# ⚠️ Lỗi API Qwen Max (Lần 1/3): Error code: 402 - {'id': 'omR9A1A-2j9zxn-a04dd22bee6d9fc2', 'error': {'message': "Credit limit exceeded, please [add credits](https://api.together.ai/settings/billing). If you've already made a payment, please wait up to 5 minutes for balances to update and try again.", 'type': 'credit_limit', 'param': None, 'code': None}}

# %%
import pandas as pd
df =pd.read_csv('gold_labeled_llama_70B.csv')
df
# Out:
#      platform     video_id                                    video_url  \
# 0     youtube  HyDxRTBnwNM  https://www.youtube.com/watch?v=HyDxRTBnwNM
# 1     youtube  HyDxRTBnwNM  https://www.youtube.com/watch?v=HyDxRTBnwNM
# 2     youtube  HyDxRTBnwNM  https://www.youtube.com/watch?v=HyDxRTBnwNM
# 3     youtube  HyDxRTBnwNM  https://www.youtube.com/watch?v=HyDxRTBnwNM
# 4     youtube  HyDxRTBnwNM  https://www.youtube.com/watch?v=HyDxRTBnwNM
# ...       ...          ...                                          ...
# 7973  youtube  HyDxRTBnwNM  https://www.youtube.com/watch?v=HyDxRTBnwNM
# 7974  youtube  HyDxRTBnwNM  https://www.youtube.com/watch?v=HyDxRTBnwNM
# 7975  youtube  HyDxRTBnwNM  https://www.youtube.com/watch?v=HyDxRTBnwNM
# 7976  youtube  HyDxRTBnwNM  https://www.youtube.com/watch?v=HyDxRTBnwNM
# 7977  youtube  HyDxRTBnwNM  https://www.youtube.com/watch?v=HyDxRTBnwNM
#
#                                video_title  \
# 0     Huyền Thoại Đa Tình Páp-Lô Pi-Cát-Xô
# 1     Huyền Thoại Đa Tình Páp-Lô Pi-Cát-Xô
# 2     Huyền Thoại Đa Tình Páp-Lô Pi-Cát-Xô
# 3     Huyền Thoại Đa Tình Páp-Lô Pi-Cát-Xô
# 4     Huyền Thoại Đa Tình Páp-Lô Pi-Cát-Xô
# ...                                    ...
# 7973  Huyền Thoại Đa Tình Páp-Lô Pi-Cát-Xô
# 7974  Huyền Thoại Đa Tình Páp-Lô Pi-Cát-Xô
# 7975  Huyền Thoại Đa Tình Páp-Lô Pi-Cát-Xô
# 7976  Huyền Thoại Đa Tình Páp-Lô Pi-Cát-Xô
# 7977  Huyền Thoại Đa Tình Páp-Lô Pi-Cát-Xô
#
#                                      video_core_content  \
# 0     Video hoạt hình vẽ tay mang phong cách hài hướ...
# 1     Video hoạt hình vẽ tay mang phong cách hài hướ...
# 2     Video hoạt hình vẽ tay mang phong cách hài hướ...
# 3     Video hoạt hình vẽ tay mang phong cách hài hướ...
# 4     Video hoạt hình vẽ tay mang phong cách hài hướ...
# ...                                                 ...
# 7973  Video hoạt hình vẽ tay mang phong cách hài hướ...
# 7974  Video hoạt hình vẽ tay mang phong cách hài hướ...
# 7975  Video hoạt hình vẽ tay mang phong cách hài hướ...
# 7976  Video hoạt hình vẽ tay mang phong cách hài hướ...
# 7977  Video hoạt hình vẽ tay mang phong cách hài hướ...
#
#      video_target_sentiment  \
# 0                   neutral
# 1                   neutral
# 2                   neutral
# 3                   neutral
# 4                   neutral
# ...                     ...
# 7973                neutral
# 7974                neutral
# 7975                neutral
# 7976                neutral
# 7977                neutral
#
#                                         video_highlight  \
# 0     Giải thích về trường phái lập thể, các giai đo...
# 1     Giải thích về trường phái lập thể, các giai đo...
# 2     Giải thích về trường phái lập thể, các giai đo...
# 3     Giải thích về trường phái lập thể, các giai đo...
# 4     Giải thích về trường phái lập thể, các giai đo...
# ...                                                 ...
# 7973  Giải thích về trường phái lập thể, các giai đo...
# 7974  Giải thích về trường phái lập thể, các giai đo...
# 7975  Giải thích về trường phái lập thể, các giai đo...
# 7976  Giải thích về trường phái lập thể, các giai đo...
# 7977  Giải thích về trường phái lập thể, các giai đo...
#
#                                                 comment  \
# 0                       bác pi cát xô là bạn của bác hồ
# 1                                    cấm sừng nhiều thế
# 2     cho ai chưa biết thì những người đó đều là nic...
# 3                      tên bài nhạc là gì vậy mọi người
# 4                       picasso năm 10 14t đẹp trai vãi
# ...                                                 ...
# 7973  cho em hỏi học vẽ sơn dầu thì phía sau đó học ...
# 7974                                        đợi lâu quá
# 7975                          nhiều vợ và nhiều đào vãi
# 7976  căng cọt to một chút đồng ý hảo hán :face_with...
# 7977                                            hảo tên
#
#                                             commonsense  sarcasm_label  \
# 0     Theo một số ghi chép lịch sử và giai thoại, Ch...  Non-Sarcastic
# 1     'Cấm sừng' là lỗi gõ phím của từ 'cắm sừng', m...  Non-Sarcastic
# 2     Nicki Minaj là một nữ ca sĩ người Mỹ nổi tiếng...  Non-Sarcastic
# 3     Không có thông tin về tên bài nhạc trong bình ...  Non-Sarcastic
# 4     Pablo Picasso sinh năm 1881 và qua đời năm 197...  Non-Sarcastic
# ...                                                 ...            ...
# 7973  Vẽ sơn dầu và animation là hai kỹ năng nghệ th...            NaN
# 7974  Cụm từ 'đợi lâu quá' là một cách nói thể hiện ...            NaN
# 7975  Cụm từ 'nhiều vợ và nhiều đào vãi' là một cách...            NaN
# 7976  Cụm từ 'căng cọt' là một cách nói về sự tự tin...            NaN
# 7977  Câu hỏi trong bình luận này thể hiện sự quan t...            NaN
#
#                reasoning
# 0     Không có mâu thuẫn
# 1     Không có mâu thuẫn
# 2     Không có mâu thuẫn
# 3     Không có mâu thuẫn
# 4     Không có mâu thuẫn
# ...                  ...
# 7973                 NaN
# 7974                 NaN
# 7975                 NaN
# 7976                 NaN
# 7977                 NaN
#
# [7978 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7978 entries, 0 to 7977
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   platform                7978 non-null   str
#  1   video_id                7978 non-null   str
#  2   video_url               7978 non-null   str
#  3   video_title             7978 non-null   str
#  4   video_core_content      7978 non-null   str
#  5   video_target_sentiment  7978 non-null   str
#  6   video_highlight         7978 non-null   str
#  7   comment                 7975 non-null   str
#  8   commonsense             7917 non-null   str
#  9   sarcasm_label           4512 non-null   str
#  10  reasoning               4512 non-null   str
# dtypes: str(11)
# memory usage: 685.7 KB
