# %%
import pandas as pd
import numpy as np
import torch
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, f1_score
from pyvi import ViTokenizer
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/_ops.py:1442, in _Ops.load_library(self, path)
#    1441 try:
# -> 1442     ctypes.CDLL(path)
#    1443 except Exception as e:
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/ctypes/__init__.py:376, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     375 if handle is None:
# --> 376     self._handle = _dlopen(self._name, mode)
#     377 else:
#
# OSError: /home/check/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/torchaudio/lib/libtorchaudio.so: undefined symbol: _ZN3c104cuda29c10_cuda_check_implementationEiPKcS2_ib
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 5
#       3 import torch
#       4 from datasets import Dataset
# ----> 5 from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer
#       6 from sklearn.preprocessing import LabelEncoder
#       7 from sklearn.metrics import classification_report, f1_score
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/utils/import_utils.py:2262, in _LazyModule.__getattr__(self, name)
#    2260 elif name in self._class_to_module:
#    2261     try:
# -> 2262         module = self._get_module(self._class_to_module[name])
#    2263         value = getattr(module, name)
#    2264     except (ModuleNotFoundError, RuntimeError, AttributeError) as e:
#    2265         # V5: If trying to import a *TokenizerFast symbol, transparently fall back to the
#    2266         # non-Fast symbol from the same module when available. This lets us keep only one
#    2267         # backend tokenizer class while preserving legacy public names.
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/utils/import_utils.py:2496, in _LazyModule._get_module(self, module_name)
#    2494     return importlib.import_module("." + module_name, self.__name__)
#    2495 except Exception as e:
# -> 2496     raise e
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/utils/import_utils.py:2494, in _LazyModule._get_module(self, module_name)
#    2492 def _get_module(self, module_name: str):
#    2493     try:
# -> 2494         return importlib.import_module("." + module_name, self.__name__)
#    2495     except Exception as e:
#    2496         raise e
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/training_args.py:27
#      24 from typing import Any, Literal
#      26 from .debug_utils import DebugOption
# ---> 27 from .trainer_utils import (
#      28     FSDPOption,
#      29     HubStrategy,
#      30     IntervalStrategy,
#      31     SaveStrategy,
#      32     SchedulerType,
#      33 )
#      34 from .utils import (
#      35     ACCELERATE_MIN_VERSION,
#      36     ExplicitEnum,
#    (...)
#      55     requires_backends,
#      56 )
#      57 from .utils.generic import strtobool
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/trainer_utils.py:66
#      63     from safetensors.torch import load_file as safe_load_file
#      65 if is_peft_available() and is_torch_available():
# ---> 66     from peft import PeftMixedModel, PeftModel
#      69 def _is_peft_model(model):
#      70     if is_peft_available():
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/peft/__init__.py:17
#       1 # Copyright 2023-present the HuggingFace Inc. team.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 __version__ = "0.19.1"
# ---> 17 from .auto import (
#      18     MODEL_TYPE_TO_PEFT_MODEL_MAPPING,
#      19     AutoPeftModel,
#      20     AutoPeftModelForCausalLM,
#      21     AutoPeftModelForFeatureExtraction,
#      22     AutoPeftModelForQuestionAnswering,
#      23     AutoPeftModelForSeq2SeqLM,
#      24     AutoPeftModelForSequenceClassification,
#      25     AutoPeftModelForTokenClassification,
#      26 )
#      27 from .config import PeftConfig, PromptLearningConfig
#      28 from .mapping import (
#      29     PEFT_TYPE_TO_CONFIG_MAPPING,
#      30     PEFT_TYPE_TO_MIXED_MODEL_MAPPING,
#    (...)
#      33     inject_adapter_in_model,
#      34 )
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/peft/auto.py:31
#      19 from typing import Optional
#      21 from transformers import (
#      22     AutoModel,
#      23     AutoModelForCausalLM,
#    (...)
#      28     AutoTokenizer,
#      29 )
# ---> 31 from .config import PeftConfig
#      32 from .peft_model import (
#      33     PeftModel,
#      34     PeftModelForCausalLM,
#    (...)
#      39     PeftModelForTokenClassification,
#      40 )
#      41 from .utils.constants import TOKENIZER_CONFIG_NAME
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/peft/config.py:30
#      26 from transformers.utils import PushToHubMixin, http_user_agent
#      28 from peft import __version__
# ---> 30 from .utils import CONFIG_NAME, PeftType, TaskType
#      33 # we expect at least these keys to be present in a PEFT adapter_config.json
#      34 MIN_EXPECTED_CONFIG_KEYS = {"peft_type"}
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/peft/utils/__init__.py:15
#       1 # Copyright 2023-present the HuggingFace Inc. team.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 from .constants import ALLOWED_COMPUTE_DTYPES, UPCAST_DTYPES
#      16 from .integrations import map_cache_to_layer_device_map
#      17 from .loftq_utils import replace_lora_weights_loftq
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/peft/utils/constants.py:16
#       1 # Copyright 2023-present the HuggingFace Inc. team.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 import torch
# ---> 16 from transformers import BloomPreTrainedModel
#      18 from ..import_utils import is_transformers_le_4_53
#      21 # needed for prefix-tuning of bloom model
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/utils/import_utils.py:2262, in _LazyModule.__getattr__(self, name)
#    2260 elif name in self._class_to_module:
#    2261     try:
# -> 2262         module = self._get_module(self._class_to_module[name])
#    2263         value = getattr(module, name)
#    2264     except (ModuleNotFoundError, RuntimeError, AttributeError) as e:
#    2265         # V5: If trying to import a *TokenizerFast symbol, transparently fall back to the
#    2266         # non-Fast symbol from the same module when available. This lets us keep only one
#    2267         # backend tokenizer class while preserving legacy public names.
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/utils/import_utils.py:2496, in _LazyModule._get_module(self, module_name)
#    2494     return importlib.import_module("." + module_name, self.__name__)
#    2495 except Exception as e:
# -> 2496     raise e
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/utils/import_utils.py:2494, in _LazyModule._get_module(self, module_name)
#    2492 def _get_module(self, module_name: str):
#    2493     try:
# -> 2494         return importlib.import_module("." + module_name, self.__name__)
#    2495     except Exception as e:
#    2496         raise e
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/models/bloom/modeling_bloom.py:26
#      24 from ...generation import GenerationMixin
#      25 from ...masking_utils import create_causal_mask
# ---> 26 from ...modeling_layers import GradientCheckpointingLayer
#      27 from ...modeling_outputs import (
#      28     BaseModelOutputWithPastAndCrossAttentions,
#      29     CausalLMOutputWithCrossAttentions,
#    (...)
#      32     TokenClassifierOutput,
#      33 )
#      34 from ...modeling_utils import PreTrainedModel
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/modeling_layers.py:27
#      20 from .modeling_outputs import (
#      21     BaseModelOutputWithPast,
#      22     QuestionAnsweringModelOutput,
#      23     SequenceClassifierOutputWithPast,
#      24     TokenClassifierOutput,
#      25 )
#      26 from .models.auto import AutoModel
# ---> 27 from .processing_utils import Unpack
#      28 from .utils import TransformersKwargs, auto_docstring, can_return_tuple, logging
#      31 logger = logging.get_logger(__name__)
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/processing_utils.py:83
#      80 if is_torch_available():
#      81     import torch
# ---> 83     from .modeling_utils import PreTrainedAudioTokenizerBase
#      85 if is_vision_available():
#      86     from .image_utils import PILImageResampling
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/modeling_utils.py:87
#      77 from .integrations.sdpa_paged import sdpa_attention_paged_forward
#      78 from .integrations.tensor_parallel import (
#      79     ALL_PARALLEL_STYLES,
#      80     _get_parameter_tp_plan,
#    (...)
#      85     verify_tp_plan,
#      86 )
# ---> 87 from .loss.loss_utils import LOSS_MAPPING
#      88 from .modeling_flash_attention_utils import (
#      89     FLASH_ATTENTION_COMPATIBILITY_MATRIX,
#      90     FLASH_ATTN_KERNEL_FALLBACK,
#      91     lazy_import_flash_attention,
#      92     lazy_import_paged_flash_attention,
#      93 )
#      94 from .modeling_rope_utils import ROPE_INIT_FUNCTIONS
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/loss/loss_utils.py:27
#      25 from .loss_lw_detr import LwDetrForObjectDetectionLoss
#      26 from .loss_rf_detr import RfDetrForSegmentationLoss
# ---> 27 from .loss_rnnt import ParakeetForRNNTLoss
#      28 from .loss_rt_detr import RTDetrForObjectDetectionLoss
#      29 from .loss_tdt import ParakeetForTDTLoss
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/transformers/loss/loss_rnnt.py:23
#      20 logger = logging.get_logger(__name__)
#      22 if is_torchaudio_available():
# ---> 23     import torchaudio
#      26 def rnnt_loss(
#      27     logits: torch.Tensor,
#      28     targets: torch.Tensor,
#    (...)
#      32     reduction: str = "mean_volume",
#      33 ) -> torch.Tensor:
#      34     """
#      35     Compute standard RNN-T (RNN Transducer) loss (https://huggingface.co/papers/1211.3711).
#      36
#    (...)
#      59
#      60     """
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/torchaudio/__init__.py:2
#       1 # Initialize extension and backend first
# ----> 2 from . import _extension  # noqa  # usort: skip
#       3 from ._backend import (  # noqa  # usort: skip
#       4     AudioMetaData,
#       5     get_audio_backend,
#    (...)
#      10     set_audio_backend,
#      11 )
#      13 from . import (  # noqa: F401
#      14     compliance,
#      15     datasets,
#    (...)
#      23     utils,
#      24 )
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/torchaudio/_extension/__init__.py:38
#      36 _IS_ALIGN_AVAILABLE = False
#      37 if _IS_TORCHAUDIO_EXT_AVAILABLE:
# ---> 38     _load_lib("libtorchaudio")
#      40     import torchaudio.lib._torchaudio  # noqa
#      42     _check_cuda_version()
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/torchaudio/_extension/utils.py:60, in _load_lib(lib)
#      58 if not path.exists():
#      59     return False
# ---> 60 torch.ops.load_library(path)
#      61 return True
#
# File ~/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/torch/_ops.py:1444, in _Ops.load_library(self, path)
#    1442         ctypes.CDLL(path)
#    1443     except Exception as e:
# -> 1444         raise OSError(f"Could not load this library: {path}") from e
#    1445 self.loaded_libraries.add(path)
#
# OSError: Could not load this library: /home/check/Programs/anaconda3/envs/myenv/lib/python3.11/site-packages/torchaudio/lib/libtorchaudio.so

# %%
train_df = pd.read_csv("train_data.csv")
test_df = pd.read_csv("test_data.csv")

# Xử lý các giá trị NaN
train_df['sarcasm_type'] = train_df['sarcasm_type'].fillna("None")
test_df['sarcasm_type'] = test_df['sarcasm_type'].fillna("None")

# CHIẾN LƯỢC CÂN BẰNG DỮ LIỆU (RESAMPLING)
print("Tỉ lệ trước khi cân bằng:\n", train_df['sarcasm_label'].value_counts())

# Tách nhóm
df_non = train_df[train_df['sarcasm_label'] == 'Non-Sarcastic']
df_sar = train_df[train_df['sarcasm_label'] == 'Sarcastic']

# 1. Undersample: Giảm Non-Sarcastic xuống 1500 mẫu
df_non_sampled = df_non.sample(n=1500, random_state=42)

# 2. Oversample: Nhân bản từng Sarcasm Type lên tối thiểu 150 mẫu
oversampled_list = []
for s_type in df_sar['sarcasm_type'].unique():
    df_type = df_sar[df_sar['sarcasm_type'] == s_type]
    target_count = max(150, len(df_type)) # Nếu đã > 150 thì giữ nguyên, nhỏ hơn thì nhân bản
    df_type_sampled = df_type.sample(n=target_count, replace=True, random_state=42)
    oversampled_list.append(df_type_sampled)

df_sar_balanced = pd.concat(oversampled_list)

# 3. Gộp lại và xáo trộn ngẫu nhiên
train_df = pd.concat([df_non_sampled, df_sar_balanced]).sample(frac=1.0, random_state=42).reset_index(drop=True)
print("Tỉ lệ sau khi cân bằng:\n", train_df['sarcasm_type'].value_counts())

# TẠO NHÃN 6 CLASS CHO BÀI TOÁN PHÂN LOẠI
def get_6_labels(row):
    if row['sarcasm_label'] == 'Non-Sarcastic': return 'Non-Sarcastic'
    if pd.isna(row['sarcasm_type']) or row['sarcasm_type'] == 'None': return 'Propositional Contradiction'
    return row['sarcasm_type']

train_df['final_label'] = train_df.apply(get_6_labels, axis=1)
test_df['final_label'] = test_df.apply(get_6_labels, axis=1)

# Mã hóa nhãn chữ thành số (0 -> 5)
le = LabelEncoder()
train_df['label'] = le.fit_transform(train_df['final_label'])
test_df['label'] = le.transform(test_df['final_label'])

# %%
def segment_text(text):
    return ViTokenizer.tokenize(str(text))

# Tách từ riêng rẽ cho Video và Comment
train_df['video_seg'] = train_df['video_core_content'].apply(segment_text)
train_df['comment_seg'] = train_df['comment'].apply(segment_text)

test_df['video_seg'] = test_df['video_core_content'].apply(segment_text)
test_df['comment_seg'] = test_df['comment'].apply(segment_text)

# Đưa vào Dataset
train_ds = Dataset.from_pandas(train_df[['video_seg', 'comment_seg', 'label']])
test_ds = Dataset.from_pandas(test_df[['video_seg', 'comment_seg', 'label']])

model_name = "vinai/phobert-base-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)

def tokenize_function(examples):
    # Truyền tách biệt video và comment để Tokenizer hiểu 2 vế
    return tokenizer(
        examples["video_seg"], 
        examples["comment_seg"], 
        padding="max_length", 
        truncation="only_first", # BẢO VỆ COMMENT KHÔNG BỊ CẮT
        max_length=256
    )

train_tokenized = train_ds.map(tokenize_function, batched=True)
test_tokenized = test_ds.map(tokenize_function, batched=True)

model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=6)

# %%
# 3. ĐÁNH GIÁ VÀ HUẤN LUYỆN
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"f1_macro": f1_score(labels, predictions, average='macro')}

training_args = TrainingArguments(
    output_dir="./phobert_results",
    learning_rate=2e-5,
    per_device_train_batch_size=16, 
    per_device_eval_batch_size=16,
    num_train_epochs=5,
    weight_decay=0.01,
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    metric_for_best_model="f1_macro",
    fp16=True, 
    warmup_ratio=0.1,
)

trainer = Trainer(
    model=model, 
    args=training_args, 
    train_dataset=train_tokenized, 
    eval_dataset=test_tokenized, 
    compute_metrics=compute_metrics,
)

print("⏳ Bắt đầu quá trình Train...")
trainer.train()

# %%
print("📊 Đang xuất báo cáo và lưu file...")
predictions = trainer.predict(test_tokenized)
y_pred = np.argmax(predictions.predictions, axis=-1)
y_true = predictions.label_ids

target_names = le.inverse_transform([0, 1, 2, 3, 4, 5])

print("="*60)
print("🏆 BÁO CÁO KẾT QUẢ PHO-BERT")
print("="*60)
print(classification_report(y_true, y_pred, target_names=target_names))

# %%
predicted_merged = le.inverse_transform(y_pred)

# Tách ngược lại thành Label và Type để chuẩn format
test_df['predicted_label'] = ['Non-Sarcastic' if p == 'Non-Sarcastic' else 'Sarcastic' for p in predicted_merged]
test_df['predicted_type'] = ['None' if p == 'Non-Sarcastic' else p for p in predicted_merged]

output_file = "test_result_PhoBERT.csv"
test_df.to_csv(output_file, index=False, encoding="utf-8-sig")
print(f"✅ Đã lưu kết quả chi tiết của PhoBERT vào: {output_file}")
